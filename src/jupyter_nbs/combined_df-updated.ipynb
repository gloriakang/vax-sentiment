# %% [raw]
# # make a dataframe of node-level data
# # remove NaN values
# # save dataframe to csv
# # combined_df.to_csv('combined_df', encoding = 'utf-8')

# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from glob import glob
pd.set_option('display.mpl_style', 'default') 
# display all the columns
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)


gml_files = glob('../output/network/*/*.gml')


def calculate_graph_inf(graph):
    graph.name = filename
    info = nx.info(graph)
    print info
    ## plot spring layout
    #plt.figure(figsize=(10,10))
    #nx.draw_spring(graph, arrows=True, with_labels=True)

def highest_centrality(cent_dict):
    """Returns a tuple (node,value) with the node
    with largest value from centrality dictionary."""
    # create ordered tuple of centrality data
    cent_items = [(b,a) for (a,b) in cent_dict.iteritems()]
    # sort in descending order
    cent_items.sort()
    cent_items.reverse()
    return tuple(reversed(cent_items[0]))

# %%
# create empty dataframe with columns

data_columns = ['name',
                'sentiment'
                ]
data = pd.DataFrame(columns = data_columns)
combined_df = pd.DataFrame()

# %%
# graph = directed, ugraph = undirected

for graph_num, gml_graph in enumerate(gml_files):
    graph = nx.read_gml(gml_graph)
    ugraph = graph.to_undirected()
    # adding missing edges back
    U = graph.to_undirected(reciprocal=True)
    e = U.edges()
    ugraph.add_edges_from(e)
    (filepath, filename) = os.path.split(gml_graph)
    print('-' * 40)
    print(gml_graph)
    #calculate_graph_inf(graph)
    #calculate_graph_inf(ugraph)

    # calculate variables and save into list
    sent = filepath.split('/')[-1]
    deg_cent = nx.degree_centrality(graph)
    bet_cent = nx.betweenness_centrality(graph)
    clo_cent = nx.closeness_centrality(graph)
    
    graph_values = {'name':filename,
                    'sentiment':sent,
                    }

    data = data.append(graph_values, ignore_index=True)
    
    #
    degree = nx.degree(graph)
    deg_df = pd.DataFrame.from_dict(degree, orient = 'index')
    deg_df.columns = ['degree']
    # degree centrality
    deg_cent = nx.degree_centrality(graph)
    dc_df = pd.DataFrame.from_dict(deg_cent, orient = 'index')
    dc_df.columns = ['degree centrality']
    # betweenness centrality
    bet_cent = nx.betweenness_centrality(graph)
    bc_df = pd.DataFrame.from_dict(bet_cent, orient = 'index')
    bc_df.columns = ['betweenness centrality']
    # closeness centrality
    clo_cent = nx.closeness_centrality(graph)
    cc_df = pd.DataFrame.from_dict(clo_cent, orient = 'index')
    cc_df.columns = ['closeness centrality']
    
    # concat node frames into node_df
    frames = [deg_df, dc_df, bc_df, cc_df]
    node_df = pd.concat(frames, axis = 1)
    node_df.index.name = 'node'
    node_df = node_df.reset_index()
    
    values = pd.DataFrame(graph_values, columns = ('name', 'sentiment'), index = [0])
    
    # df = merges graph_values with node_df for single graph and fill NaNs
    df = pd.concat([values, node_df], axis = 1)
    df = df.fillna(method='ffill')
    
    # append to combined_df
    combined_df = combined_df.append(df)
    
#    if graph_num == 2:
#        break
# Out:
# ----------------------------------------
# ../output/network/positive/article2.gml
# ----------------------------------------
# ../output/network/positive/article1804.gml
# ----------------------------------------
# ../output/network/positive/article6247.gml
# ----------------------------------------
# ../output/network/positive/article4150.gml
# ----------------------------------------
# ../output/network/positive/article1105.gml
# ----------------------------------------
# ../output/network/positive/article5077.gml
# ----------------------------------------
# ../output/network/positive/article111.gml
# ----------------------------------------
# ../output/network/positive/article828.gml
# ----------------------------------------
# ../output/network/positive/article665.gml
# ----------------------------------------
# ../output/network/positive/article664.gml
# ----------------------------------------
# ../output/network/positive/article1542.gml
# ----------------------------------------
# ../output/network/positive/article4303.gml
# ----------------------------------------
# ../output/network/positive/article36.gml
# ----------------------------------------
# ../output/network/positive/article4210.gml
# ----------------------------------------
# ../output/network/positive/article620.gml
# ----------------------------------------
# ../output/network/positive/article31.gml
# ----------------------------------------
# ../output/network/positive/article5.gml
# ----------------------------------------
# ../output/network/positive/article29.gml
# ----------------------------------------
# ../output/network/positive/article46.gml
# ----------------------------------------
# ../output/network/positive/article30.gml
# ----------------------------------------
# ../output/network/positive/article609.gml
# ----------------------------------------
# ../output/network/positive/article02.gml
# ----------------------------------------
# ../output/network/positive/article37.gml
# ----------------------------------------
# ../output/network/neutral/article54.gml
# ----------------------------------------
# ../output/network/neutral/article532.gml
# ----------------------------------------
# ../output/network/neutral/article756.gml
# ----------------------------------------
# ../output/network/neutral/article647.gml
# ----------------------------------------
# ../output/network/neutral/article2047.gml
# ----------------------------------------
# ../output/network/neutral/article63.gml
# ----------------------------------------
# ../output/network/negative/article432.gml
# ----------------------------------------
# ../output/network/negative/article06.gml
# ----------------------------------------
# ../output/network/negative/article1.gml
# ----------------------------------------
# ../output/network/negative/article99.gml
# ----------------------------------------
# ../output/network/negative/article05.gml
# ----------------------------------------
# ../output/network/negative/article774.gml
# ----------------------------------------
# ../output/network/negative/article782.gml
# ----------------------------------------
# ../output/network/negative/article152.gml
# ----------------------------------------
# ../output/network/negative/article4106.gml
# ----------------------------------------
# ../output/network/negative/article5717.gml
# ----------------------------------------
# ../output/network/negative/article621.gml
# ----------------------------------------
# ../output/network/negative/article03.gml
# ----------------------------------------
# ../output/network/negative/article5164.gml
# ----------------------------------------
# ../output/network/negative/article2308.gml
# ----------------------------------------
# ../output/network/negative/article5813.gml
# ----------------------------------------
# ../output/network/negative/article683.gml
# ----------------------------------------
# ../output/network/negative/article07.gml
# ----------------------------------------
# ../output/network/negative/article1021.gml
# ----------------------------------------
# ../output/network/negative/article3335.gml
# ----------------------------------------
# ../output/network/negative/article1001.gml
# ----------------------------------------
# ../output/network/negative/article703.gml

# %%
combined_df
# Out:
#                 name sentiment                                         node  degree  degree centrality  betweenness centrality  closeness centrality
# 0       article2.gml  positive              spread of communicable diseases       1           0.037037                0.000000              0.000000
# 1       article2.gml  positive           choosing not to vaccinate children       3           0.111111                0.000000              0.000000
# 2       article2.gml  positive                            religious reasons       2           0.074074                0.000000              0.000000
# 3       article2.gml  positive                                    childcare       1           0.037037                0.000000              0.000000
# 4       article2.gml  positive                                medical issue       2           0.074074                0.002849              0.037037
# 5       article2.gml  positive                                 kindergarten       1           0.037037                0.000000              0.000000
# 6       article2.gml  positive                                  vaccination       1           0.037037                0.000000              0.000000
# 7       article2.gml  positive                             personal beliefs       1           0.037037                0.000000              0.000000
# 8       article2.gml  positive                                     children       1           0.037037                0.000000              0.092593
# 9       article2.gml  positive                                     vaccines       1           0.037037                0.000000              0.037037
# 10      article2.gml  positive                change in mindset of families       1           0.037037                0.000000              0.000000
# 11      article2.gml  positive                                     concerns       1           0.037037                0.000000              0.000000
# 12      article2.gml  positive                                      parents       3           0.111111                0.000000              0.111111
# 13      article2.gml  positive                                herd immunity       1           0.037037                0.000000              0.000000
# 14      article2.gml  positive                     interest in vaccinations       1           0.037037                0.000000              0.000000
# 15      article2.gml  positive                      personal belief reasons       1           0.037037                0.000000              0.000000
# 16      article2.gml  positive                        required vaccinations       4           0.148148                0.005698              0.118519
# 17      article2.gml  positive                                     families       3           0.111111                0.000000              0.037037
# 18      article2.gml  positive                                    good news       1           0.037037                0.000000              0.000000
# 19      article2.gml  positive                                      measles       1           0.037037                0.000000              0.000000
# 20      article2.gml  positive                                public health       1           0.037037                0.000000              0.037037
# 21      article2.gml  positive                            medical exemption       1           0.037037                0.000000              0.000000
# 22      article2.gml  positive                                        fluke       1           0.037037                0.000000              0.000000
# 23      article2.gml  positive         Arizona Deparment of Health Services       1           0.037037                0.000000              0.121212
# 24      article2.gml  positive                          Disneyland outbreak       2           0.074074                0.000000              0.074074
# 25      article2.gml  positive                  decrease in exemption rates       6           0.222222                0.007123              0.185185
# 26      article2.gml  positive                              exemption rates       2           0.074074                0.000000              0.074074
# 27      article2.gml  positive        Arizona Department of Health Services       1           0.037037                0.000000              0.000000
# 0    article1804.gml  positive                      new version of Gardasil       3           0.073171                0.000000              0.104065
# 1    article1804.gml  positive                       positive health impact       2           0.048780                0.000610              0.024390
# ..               ...       ...                                          ...     ...                ...                     ...                   ...
# 252   article703.gml  negative                           threat of job loss       1           0.003559                0.000000              0.003559
# 253   article703.gml  negative              toxic and ineffective flu shots       5           0.017794                0.000051              0.014235
# 254   article703.gml  negative                                     toxicity       1           0.003559                0.000000              0.000000
# 255   article703.gml  negative                                       travel       1           0.003559                0.000000              0.000000
# 256   article703.gml  negative  trusted voices in defense of vaccine safety       1           0.003559                0.000000              0.003559
# 257   article703.gml  negative                      unfair market practices       2           0.007117                0.000038              0.003559
# 258   article703.gml  negative                                 unvaccinated       1           0.003559                0.000000              0.000000
# 259   article703.gml  negative             unvaccinated health care workers       1           0.003559                0.000000              0.000000
# 260   article703.gml  negative                                  vaccination       1           0.003559                0.000000              0.004745
# 261   article703.gml  negative                         vaccination coverage       3           0.010676                0.000025              0.003559
# 262   article703.gml  negative                         vaccination schedule       2           0.007117                0.000013              0.003559
# 263   article703.gml  negative                                 vaccinations       2           0.007117                0.000000              0.015184
# 264   article703.gml  negative                      vaccinations save lives       1           0.003559                0.000000              0.000000
# 265   article703.gml  negative                                      vaccine       2           0.007117                0.000025              0.003559
# 266   article703.gml  negative                        vaccine effectiveness       1           0.003559                0.000000              0.000000
# 267   article703.gml  negative                             vaccine efficacy       1           0.003559                0.000000              0.000000
# 268   article703.gml  negative                             vaccine industry      13           0.046263                0.000254              0.045919
# 269   article703.gml  negative                               vaccine makers       2           0.007117                0.000013              0.003559
# 270   article703.gml  negative                             vaccine mandates       3           0.010676                0.000000              0.000000
# 271   article703.gml  negative                        vaccine manufacturers       1           0.003559                0.000000              0.003559
# 272   article703.gml  negative                           vaccine proponents       2           0.007117                0.000000              0.027459
# 273   article703.gml  negative                                vaccine risks       1           0.003559                0.000000              0.000000
# 274   article703.gml  negative                               vaccine safety       2           0.007117                0.000000              0.000000
# 275   article703.gml  negative                                     vaccines      22           0.078292                0.003076              0.052195
# 276   article703.gml  negative                                        value       1           0.003559                0.000000              0.003559
# 277   article703.gml  negative              voluntary vaccination decisions       1           0.003559                0.000000              0.000000
# 278   article703.gml  negative                               whooping cough       1           0.003559                0.000000              0.000000
# 279   article703.gml  negative                   widespread health problems       2           0.007117                0.000000              0.015184
# 280   article703.gml  negative                  world's healthiest children       1           0.003559                0.000000              0.000000
# 281   article703.gml  negative                                 young adults       1           0.003559                0.000000              0.000000
#
# [3351 rows x 7 columns]

# %%
# save dataframe to csv
combined_df.to_csv('combined_df', encoding = 'utf-8')

# %% [markdown]
# - - -

# %% [raw]
# #### read the thing ####

# %%
combined_df = pd.read_csv('combined_df')
combined_df
# Out:
#       Unnamed: 0             name sentiment                                         node  degree  degree centrality  betweenness centrality  closeness centrality
# 0              0     article2.gml  positive              spread of communicable diseases       1           0.037037                0.000000              0.000000
# 1              1     article2.gml  positive           choosing not to vaccinate children       3           0.111111                0.000000              0.000000
# 2              2     article2.gml  positive                            religious reasons       2           0.074074                0.000000              0.000000
# 3              3     article2.gml  positive                                    childcare       1           0.037037                0.000000              0.000000
# 4              4     article2.gml  positive                                medical issue       2           0.074074                0.002849              0.037037
# 5              5     article2.gml  positive                                 kindergarten       1           0.037037                0.000000              0.000000
# 6              6     article2.gml  positive                                  vaccination       1           0.037037                0.000000              0.000000
# 7              7     article2.gml  positive                             personal beliefs       1           0.037037                0.000000              0.000000
# 8              8     article2.gml  positive                                     children       1           0.037037                0.000000              0.092593
# 9              9     article2.gml  positive                                     vaccines       1           0.037037                0.000000              0.037037
# 10            10     article2.gml  positive                change in mindset of families       1           0.037037                0.000000              0.000000
# 11            11     article2.gml  positive                                     concerns       1           0.037037                0.000000              0.000000
# 12            12     article2.gml  positive                                      parents       3           0.111111                0.000000              0.111111
# 13            13     article2.gml  positive                                herd immunity       1           0.037037                0.000000              0.000000
# 14            14     article2.gml  positive                     interest in vaccinations       1           0.037037                0.000000              0.000000
# 15            15     article2.gml  positive                      personal belief reasons       1           0.037037                0.000000              0.000000
# 16            16     article2.gml  positive                        required vaccinations       4           0.148148                0.005698              0.118519
# 17            17     article2.gml  positive                                     families       3           0.111111                0.000000              0.037037
# 18            18     article2.gml  positive                                    good news       1           0.037037                0.000000              0.000000
# 19            19     article2.gml  positive                                      measles       1           0.037037                0.000000              0.000000
# 20            20     article2.gml  positive                                public health       1           0.037037                0.000000              0.037037
# 21            21     article2.gml  positive                            medical exemption       1           0.037037                0.000000              0.000000
# 22            22     article2.gml  positive                                        fluke       1           0.037037                0.000000              0.000000
# 23            23     article2.gml  positive         Arizona Deparment of Health Services       1           0.037037                0.000000              0.121212
# 24            24     article2.gml  positive                          Disneyland outbreak       2           0.074074                0.000000              0.074074
# 25            25     article2.gml  positive                  decrease in exemption rates       6           0.222222                0.007123              0.185185
# 26            26     article2.gml  positive                              exemption rates       2           0.074074                0.000000              0.074074
# 27            27     article2.gml  positive        Arizona Department of Health Services       1           0.037037                0.000000              0.000000
# 28             0  article1804.gml  positive                      new version of Gardasil       3           0.073171                0.000000              0.104065
# 29             1  article1804.gml  positive                       positive health impact       2           0.048780                0.000610              0.024390
# ...          ...              ...       ...                                          ...     ...                ...                     ...                   ...
# 3321         252   article703.gml  negative                           threat of job loss       1           0.003559                0.000000              0.003559
# 3322         253   article703.gml  negative              toxic and ineffective flu shots       5           0.017794                0.000051              0.014235
# 3323         254   article703.gml  negative                                     toxicity       1           0.003559                0.000000              0.000000
# 3324         255   article703.gml  negative                                       travel       1           0.003559                0.000000              0.000000
# 3325         256   article703.gml  negative  trusted voices in defense of vaccine safety       1           0.003559                0.000000              0.003559
# 3326         257   article703.gml  negative                      unfair market practices       2           0.007117                0.000038              0.003559
# 3327         258   article703.gml  negative                                 unvaccinated       1           0.003559                0.000000              0.000000
# 3328         259   article703.gml  negative             unvaccinated health care workers       1           0.003559                0.000000              0.000000
# 3329         260   article703.gml  negative                                  vaccination       1           0.003559                0.000000              0.004745
# 3330         261   article703.gml  negative                         vaccination coverage       3           0.010676                0.000025              0.003559
# 3331         262   article703.gml  negative                         vaccination schedule       2           0.007117                0.000013              0.003559
# 3332         263   article703.gml  negative                                 vaccinations       2           0.007117                0.000000              0.015184
# 3333         264   article703.gml  negative                      vaccinations save lives       1           0.003559                0.000000              0.000000
# 3334         265   article703.gml  negative                                      vaccine       2           0.007117                0.000025              0.003559
# 3335         266   article703.gml  negative                        vaccine effectiveness       1           0.003559                0.000000              0.000000
# 3336         267   article703.gml  negative                             vaccine efficacy       1           0.003559                0.000000              0.000000
# 3337         268   article703.gml  negative                             vaccine industry      13           0.046263                0.000254              0.045919
# 3338         269   article703.gml  negative                               vaccine makers       2           0.007117                0.000013              0.003559
# 3339         270   article703.gml  negative                             vaccine mandates       3           0.010676                0.000000              0.000000
# 3340         271   article703.gml  negative                        vaccine manufacturers       1           0.003559                0.000000              0.003559
# 3341         272   article703.gml  negative                           vaccine proponents       2           0.007117                0.000000              0.027459
# 3342         273   article703.gml  negative                                vaccine risks       1           0.003559                0.000000              0.000000
# 3343         274   article703.gml  negative                               vaccine safety       2           0.007117                0.000000              0.000000
# 3344         275   article703.gml  negative                                     vaccines      22           0.078292                0.003076              0.052195
# 3345         276   article703.gml  negative                                        value       1           0.003559                0.000000              0.003559
# 3346         277   article703.gml  negative              voluntary vaccination decisions       1           0.003559                0.000000              0.000000
# 3347         278   article703.gml  negative                               whooping cough       1           0.003559                0.000000              0.000000
# 3348         279   article703.gml  negative                   widespread health problems       2           0.007117                0.000000              0.015184
# 3349         280   article703.gml  negative                  world's healthiest children       1           0.003559                0.000000              0.000000
# 3350         281   article703.gml  negative                                 young adults       1           0.003559                0.000000              0.000000
#
# [3351 rows x 8 columns]
