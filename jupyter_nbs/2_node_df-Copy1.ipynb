# %% [markdown]
# # node_df (copy)
# 0. node-level data (all articles)
# 1. network data + centrality data = combined_df
# 2. remove NaN values
# 3. out = node_df.csv

# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from glob import glob
pd.set_option('display.mpl_style', 'default') 
# display all the columns
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)


gml_files = glob('../output/network/*.gml')


def calculate_graph_inf(graph):
    graph.name = filename
    info = nx.info(graph)
    print info
    ## plot spring layout
    #plt.figure(figsize=(10,10))
    #nx.draw_spring(graph, arrows=True, with_labels=True)

def highest_centrality(cent_dict):
    """Returns a tuple (node,value) with the node
    with largest value from centrality dictionary."""
    # create ordered tuple of centrality data
    cent_items = [(b,a) for (a,b) in cent_dict.iteritems()]
    # sort in descending order
    cent_items.sort()
    cent_items.reverse()
    return tuple(reversed(cent_items[0]))

# %%
# create empty dataframe with columns

data_columns = ['name',
                'sentiment'
                ]
data = pd.DataFrame(columns = data_columns)
combined_df = pd.DataFrame()

# %%
# graph = directed, ugraph = undirected

for graph_num, gml_graph in enumerate(gml_files):
    graph = nx.read_gml(gml_graph)
    ugraph = graph.to_undirected()
    # adding missing edges back
    U = graph.to_undirected(reciprocal=True)
    e = U.edges()
    ugraph.add_edges_from(e)
    (filepath, filename) = os.path.split(gml_graph)
    print('-' * 40)
    print(gml_graph)
    #calculate_graph_inf(graph)
    #calculate_graph_inf(ugraph)

    # calculate variables and save into list
    sent = filepath.split('/')[-1]
    deg_cent = nx.degree_centrality(graph)
    bet_cent = nx.betweenness_centrality(graph)
    clo_cent = nx.closeness_centrality(graph)
    
    graph_values = {'name':filename,
                    'sentiment':sent,
                    }

    data = data.append(graph_values, ignore_index=True)
    
    #
    degree = nx.degree(graph)
    deg_df = pd.DataFrame.from_dict(degree, orient = 'index')
    deg_df.columns = ['degree']
    # degree centrality
    deg_cent = nx.degree_centrality(graph)
    dc_df = pd.DataFrame.from_dict(deg_cent, orient = 'index')
    dc_df.columns = ['degree centrality']
    # betweenness centrality
    bet_cent = nx.betweenness_centrality(graph)
    bc_df = pd.DataFrame.from_dict(bet_cent, orient = 'index')
    bc_df.columns = ['betweenness centrality']
    # closeness centrality
    clo_cent = nx.closeness_centrality(graph)
    cc_df = pd.DataFrame.from_dict(clo_cent, orient = 'index')
    cc_df.columns = ['closeness centrality']
    
    # concat node frames into node_df
    frames = [deg_df, dc_df, bc_df, cc_df]
    node_df = pd.concat(frames, axis = 1)
    node_df.index.name = 'node'
    node_df = node_df.reset_index()
    
    values = pd.DataFrame(graph_values, columns = ('name', 'sentiment'), index = [0])
    
    # df = merges graph_values with node_df for single graph and fill NaNs
    df = pd.concat([values, node_df], axis = 1)
    df = df.fillna(method='ffill')
    
    # append to combined_df
    combined_df = combined_df.append(df)
    
#    if graph_num == 2:
#        break
# Out:
# ----------------------------------------
# ../output/network/article_neg.gml

# %%
combined_df
# Out:
#                  name sentiment                                            node  degree  degree centrality  betweenness centrality  closeness centrality
# 0     article_neg.gml   network                             religious exemption       1           0.000683            0.000000e+00              0.000000
# 1     article_neg.gml   network                                           child       8           0.005464            2.078384e-03              0.052817
# 2     article_neg.gml   network                               flu shot campaign       1           0.000683            0.000000e+00              0.001561
# 3     article_neg.gml   network                                 toxic adjuvants       2           0.001366            0.000000e+00              0.000000
# 4     article_neg.gml   network                      government health agencies       1           0.000683            0.000000e+00              0.074237
# 5     article_neg.gml   network                                   controversial       1           0.000683            0.000000e+00              0.000000
# 6     article_neg.gml   network                         swine-flu-related drugs       1           0.000683            0.000000e+00              0.000000
# 7     article_neg.gml   network                          safe level of exposure       1           0.000683            0.000000e+00              0.000000
# 8     article_neg.gml   network                              heightened emotion       2           0.001366            1.610771e-04              0.000683
# 9     article_neg.gml   network                                  Dr. Paul Offit      16           0.010929            0.000000e+00              0.086032
# 10    article_neg.gml   network                                         tremors       1           0.000683            0.000000e+00              0.000000
# 11    article_neg.gml   network                                      disability       4           0.002732            2.754696e-04              0.069714
# 12    article_neg.gml   network                                        censored       1           0.000683            0.000000e+00              0.000000
# 13    article_neg.gml   network                         flu shot while pregnant       1           0.000683            0.000000e+00              0.000683
# 14    article_neg.gml   network                        partial facial paralysis       1           0.000683            0.000000e+00              0.000000
# 15    article_neg.gml   network                         Merck's RotaTeq vaccine       2           0.001366            0.000000e+00              0.000000
# 16    article_neg.gml   network                            safe form of mercury       2           0.001366            1.610771e-04              0.000683
# 17    article_neg.gml   network                          financial compensation       7           0.004781            1.911798e-03              0.060344
# 18    article_neg.gml   network                                     legislators       2           0.001366            9.337801e-07              0.001025
# 19    article_neg.gml   network                                            risk       1           0.000683            0.000000e+00              0.000000
# 20    article_neg.gml   network                                      compassion       1           0.000683            0.000000e+00              0.000000
# 21    article_neg.gml   network                               vaccine additives      10           0.006831            3.448754e-03              0.088585
# 22    article_neg.gml   network                                        Hilleman       2           0.001366            0.000000e+00              0.057994
# 23    article_neg.gml   network                                medical industry       1           0.000683            0.000000e+00              0.065274
# 24    article_neg.gml   network                                  medical ethics       1           0.000683            0.000000e+00              0.000000
# 25    article_neg.gml   network                                          school       1           0.000683            0.000000e+00              0.000000
# 26    article_neg.gml   network                                irritable bowels       1           0.000683            0.000000e+00              0.000000
# 27    article_neg.gml   network                                 sicker children       1           0.000683            0.000000e+00              0.000000
# 28    article_neg.gml   network                                 vaccine program       1           0.000683            0.000000e+00              0.000000
# 29    article_neg.gml   network                                    Renee Gentry       2           0.001366            0.000000e+00              0.067757
# ...               ...       ...                                             ...     ...                ...                     ...                   ...
# 1435  article_neg.gml   network                   falsifying drug study results       1           0.000683            0.000000e+00              0.000000
# 1436  article_neg.gml   network                                shocking dangers       1           0.000683            0.000000e+00              0.001025
# 1437  article_neg.gml   network                                          deaths       9           0.006148            5.620126e-03              0.065646
# 1438  article_neg.gml   network                                  parent's right       3           0.002049            3.060464e-04              0.047242
# 1439  article_neg.gml   network                                    vaccine link       2           0.001366            0.000000e+00              0.001537
# 1440  article_neg.gml   network                                 vaccine results       1           0.000683            0.000000e+00              0.000000
# 1441  article_neg.gml   network                                       education       2           0.001366            0.000000e+00              0.000000
# 1442  article_neg.gml   network                                          autism      45           0.030738            2.013777e-02              0.078535
# 1443  article_neg.gml   network                                 hospitalization       1           0.000683            0.000000e+00              0.000000
# 1444  article_neg.gml   network                                 metal compounds       1           0.000683            0.000000e+00              0.000000
# 1445  article_neg.gml   network                                    measles data       1           0.000683            0.000000e+00              0.000000
# 1446  article_neg.gml   network                                     ingredients       1           0.000683            0.000000e+00              0.000683
# 1447  article_neg.gml   network  infant who died from simultaneous vaccinations       3           0.002049            9.678319e-04              0.082311
# 1448  article_neg.gml   network                     vaccine bullying curriculum       5           0.003415            2.801340e-06              0.063497
# 1449  article_neg.gml   network                                            sick       1           0.000683            0.000000e+00              0.000000
# 1450  article_neg.gml   network                                      conclusion       1           0.000683            0.000000e+00              0.000000
# 1451  article_neg.gml   network                                    Bell's Palsy       1           0.000683            0.000000e+00              0.000000
# 1452  article_neg.gml   network                                unethical advice       1           0.000683            0.000000e+00              0.000000
# 1453  article_neg.gml   network                             millions of dollars       4           0.002732            2.399426e-03              0.006030
# 1454  article_neg.gml   network                               piece of evidence       2           0.001366            3.006772e-04              0.053060
# 1455  article_neg.gml   network                              European countries       1           0.000683            0.000000e+00              0.000000
# 1456  article_neg.gml   network                         anti-vaccination stance       1           0.000683            0.000000e+00              0.000683
# 1457  article_neg.gml   network                              Royal Navy records       1           0.000683            0.000000e+00              0.002505
# 1458  article_neg.gml   network                                influenza season       1           0.000683            0.000000e+00              0.000000
# 1459  article_neg.gml   network                              Every Child by Two       2           0.001366            0.000000e+00              0.093847
# 1460  article_neg.gml   network                                        students       1           0.000683            0.000000e+00              0.076317
# 1461  article_neg.gml   network                                   peer bullying       1           0.000683            0.000000e+00              0.000000
# 1462  article_neg.gml   network                                 chronic disease       4           0.002732            2.580346e-05              0.069714
# 1463  article_neg.gml   network                              symptoms of autism       1           0.000683            0.000000e+00              0.000000
# 1464  article_neg.gml   network                            vaccine preservative       3           0.002049            3.002103e-04              0.066701
#
# [1465 rows x 7 columns]

# %%
# save dataframe to csv
combined_df.to_csv('new_negative_df.csv', encoding = 'utf-8')

# %% [markdown]
# - - -

# %%
# split into sub-tables
neg_node_df = combined_df[combined_df['sentiment'] == 'negative']
pos_node_df = combined_df[combined_df['sentiment'] == 'positive']
neu_node_df = combined_df[combined_df['sentiment'] == 'neutral']

# %%
neg_node_df.to_csv('negative_node_df.csv', encoding = 'utf-8')
pos_node_df.to_csv('positive_node_df.csv', encoding = 'utf-8')
neu_node_df.to_csv('neutral_node_df.csv', encoding = 'utf-8')

# %% [markdown]
# - - -

# %% [raw]
# #### read the thing ####

# %%
df = pd.read_csv('negative_node_df.csv')
df
