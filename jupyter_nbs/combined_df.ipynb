# %% [raw]
# # make a dataframe
# # read dataframe

# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from glob import glob
pd.set_option('display.mpl_style', 'default') 
# display all the columns
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)


gml_files = glob('../output/network/*/*.gml')


def calculate_graph_inf(graph):
    graph.name = filename
    info = nx.info(graph)
    print info
    ## plot spring layout
    #plt.figure(figsize=(10,10))
    #nx.draw_spring(graph, arrows=True, with_labels=True)

def highest_centrality(cent_dict):
    """Returns a tuple (node,value) with the node
    with largest value from centrality dictionary."""
    # create ordered tuple of centrality data
    cent_items = [(b,a) for (a,b) in cent_dict.iteritems()]
    # sort in descending order
    cent_items.sort()
    cent_items.reverse()
    return tuple(reversed(cent_items[0]))

# %%
# create empty dataframe with columns

data_columns = ['name',
                'sentiment'
                ]
data = pd.DataFrame(columns = data_columns)
combined_df = pd.DataFrame()

# %%
# graph = directed, ugraph = undirected

for graph_num, gml_graph in enumerate(gml_files):
    graph = nx.read_gml(gml_graph)
    ugraph = graph.to_undirected()
    ## adding missing edges back
    U = graph.to_undirected(reciprocal=True)
    e = U.edges()
    ugraph.add_edges_from(e)
    (filepath, filename) = os.path.split(gml_graph)
    print('-' * 40)
    print(gml_graph)
    #calculate_graph_inf(graph)
    #calculate_graph_inf(ugraph)

    # calculate variables
    sent = filepath.split('/')[-1]
    deg_cent = nx.degree_centrality(graph)
    bet_cent = nx.betweenness_centrality(graph)
    clo_cent = nx.closeness_centrality(graph)
    
    # save variables into list
    graph_values = {'name':filename,
                    'sentiment':sent,
                    }

    # appends main data df
    data = data.append(graph_values, ignore_index=True)
    
    ###########
    
    degree = nx.degree(graph)
    deg_df = pd.DataFrame.from_dict(degree, orient = 'index')
    deg_df.columns = ['degree']
    # degree centrality
    deg_cent = nx.degree_centrality(graph)
    dc_df = pd.DataFrame.from_dict(deg_cent, orient = 'index')
    dc_df.columns = ['degree centrality']
    # betweenness centrality
    bet_cent = nx.betweenness_centrality(graph)
    bc_df = pd.DataFrame.from_dict(bet_cent, orient = 'index')
    bc_df.columns = ['betweenness centrality']
    # closeness centrality
    clo_cent = nx.closeness_centrality(graph)
    cc_df = pd.DataFrame.from_dict(clo_cent, orient = 'index')
    cc_df.columns = ['closeness centrality']

    # concat node frames into node_df
    frames = [deg_df, dc_df, bc_df, cc_df]
    node_df = pd.concat(frames, axis = 1)
    node_df.index.name = 'node'
    node_df = node_df.reset_index()
    
    
    
    #### this is all kinds of fucked up ###
    values = pd.DataFrame(graph_values, columns = ('name', 'sentiment'), index = [0])
    df = pd.concat([values, node_df], axis = 1)
    
    combined_df = combined_df.append(df)
    
#    if graph_num == 3:
#        break
# Out:
# ----------------------------------------
# ../output/network/negative/article03.gml
# ----------------------------------------
# ../output/network/negative/article05.gml
# ----------------------------------------
# ../output/network/negative/article06.gml
# ----------------------------------------
# ../output/network/negative/article07.gml
# ----------------------------------------
# ../output/network/negative/article1.gml
# ----------------------------------------
# ../output/network/negative/article1001.gml
# ----------------------------------------
# ../output/network/negative/article1021.gml
# ----------------------------------------
# ../output/network/negative/article152.gml
# ----------------------------------------
# ../output/network/negative/article2308.gml
# ----------------------------------------
# ../output/network/negative/article3335.gml
# ----------------------------------------
# ../output/network/negative/article4106.gml
# ----------------------------------------
# ../output/network/negative/article432.gml
# ----------------------------------------
# ../output/network/negative/article5164.gml
# ----------------------------------------
# ../output/network/negative/article5717.gml
# ----------------------------------------
# ../output/network/negative/article5813.gml
# ----------------------------------------
# ../output/network/negative/article621.gml
# ----------------------------------------
# ../output/network/negative/article683.gml
# ----------------------------------------
# ../output/network/negative/article703.gml
# ----------------------------------------
# ../output/network/negative/article774.gml
# ----------------------------------------
# ../output/network/negative/article782.gml
# ----------------------------------------
# ../output/network/negative/article99.gml
# ----------------------------------------
# ../output/network/neutral/article2047.gml
# ----------------------------------------
# ../output/network/neutral/article532.gml
# ----------------------------------------
# ../output/network/neutral/article54.gml
# ----------------------------------------
# ../output/network/neutral/article63.gml
# ----------------------------------------
# ../output/network/neutral/article647.gml
# ----------------------------------------
# ../output/network/neutral/article756.gml
# ----------------------------------------
# ../output/network/positive/article02.gml
# ----------------------------------------
# ../output/network/positive/article1105.gml
# ----------------------------------------
# ../output/network/positive/article111.gml
# ----------------------------------------
# ../output/network/positive/article1542.gml
# ----------------------------------------
# ../output/network/positive/article1804.gml
# ----------------------------------------
# ../output/network/positive/article2.gml
# ----------------------------------------
# ../output/network/positive/article29.gml
# ----------------------------------------
# ../output/network/positive/article30.gml
# ----------------------------------------
# ../output/network/positive/article31.gml
# ----------------------------------------
# ../output/network/positive/article36.gml
# ----------------------------------------
# ../output/network/positive/article37.gml
# ----------------------------------------
# ../output/network/positive/article4150.gml
# ----------------------------------------
# ../output/network/positive/article4210.gml
# ----------------------------------------
# ../output/network/positive/article4303.gml
# ----------------------------------------
# ../output/network/positive/article46.gml
# ----------------------------------------
# ../output/network/positive/article5.gml
# ----------------------------------------
# ../output/network/positive/article5077.gml
# ----------------------------------------
# ../output/network/positive/article609.gml
# ----------------------------------------
# ../output/network/positive/article620.gml
# ----------------------------------------
# ../output/network/positive/article6247.gml
# ----------------------------------------
# ../output/network/positive/article664.gml
# ----------------------------------------
# ../output/network/positive/article665.gml
# ----------------------------------------
# ../output/network/positive/article828.gml

# %%
combined_df
# Out:
#              name sentiment                                         node  degree  degree centrality  betweenness centrality  closeness centrality
# 0   article03.gml  negative                                       parent       1           0.058824                0.000000              0.058824
# 1             NaN       NaN                              vaccine dangers       2           0.117647                0.003676              0.058824
# 2             NaN       NaN                        unvaccinated children       2           0.117647                0.011029              0.088235
# 3             NaN       NaN                        vaccines are not safe       1           0.058824                0.000000              0.000000
# 4             NaN       NaN                                         safe       1           0.058824                0.000000              0.000000
# 5             NaN       NaN  parents who know that vaccines are not safe       1           0.058824                0.000000              0.058824
# 6             NaN       NaN                     vaccine-injured children       1           0.058824                0.000000              0.000000
# 7             NaN       NaN                          vaccinated children       2           0.117647                0.000000              0.133690
# 8             NaN       NaN                                     vaccines       2           0.117647                0.011029              0.058824
# 9             NaN       NaN                                      doctors       1           0.058824                0.000000              0.058824
# 10            NaN       NaN                                      parents       3           0.176471                0.000000              0.210084
# 11            NaN       NaN                         consent for vaccines       2           0.117647                0.003676              0.058824
# 12            NaN       NaN                                immune system       2           0.117647                0.014706              0.078431
# 13            NaN       NaN                          preventable disease       1           0.058824                0.000000              0.000000
# 14            NaN       NaN                                     truthful       1           0.058824                0.000000              0.000000
# 15            NaN       NaN                                     children       1           0.058824                0.000000              0.000000
# 16            NaN       NaN                         get child vaccinated       1           0.058824                0.000000              0.000000
# 17            NaN       NaN                        vaccine consent forms       1           0.058824                0.000000              0.000000
# 0   article05.gml  negative                                   Jim Carrey       7           0.333333                0.000000              0.321429
# 1             NaN       NaN                      neurotoxins in vaccines       3           0.142857                0.004762              0.047619
# 2             NaN       NaN                           mandatory vaccines       5           0.238095                0.009524              0.142857
# 3             NaN       NaN                                controversial       1           0.047619                0.000000              0.000000
# 4             NaN       NaN                       governor of California       1           0.047619                0.000000              0.047619
# 5             NaN       NaN                                     children       1           0.047619                0.000000              0.000000
# 6             NaN       NaN                                      mercury       2           0.095238                0.000000              0.000000
# 7             NaN       NaN                              vaccine dangers       1           0.047619                0.000000              0.000000
# 8             NaN       NaN                                       SB 277       5           0.238095                0.004762              0.047619
# 9             NaN       NaN                                     vaccines       2           0.095238                0.000000              0.000000
# 10            NaN       NaN                           poisoning children       2           0.095238                0.000000              0.108844
# 11            NaN       NaN                                   thimerosal       2           0.095238                0.002381              0.047619
# ..            ...       ...                                          ...     ...                ...                     ...                   ...
# 26            NaN       NaN                                        myths       2           0.036364                0.000337              0.018182
# 27            NaN       NaN                                    officials       1           0.018182                0.000000              0.032727
# 28            NaN       NaN                                     opt-outs       1           0.018182                0.000000              0.000000
# 29            NaN       NaN                        overwhelming approval       1           0.018182                0.000000              0.000000
# 30            NaN       NaN                              parental rights       2           0.036364                0.000000              0.000000
# 31            NaN       NaN                                      parents       4           0.072727                0.000000              0.054545
# 32            NaN       NaN                                  party lines       1           0.018182                0.000000              0.000000
# 33            NaN       NaN                                       people       1           0.018182                0.000000              0.000000
# 34            NaN       NaN                    personal belief exemption       3           0.054545                0.000673              0.036364
# 35            NaN       NaN                   personal belief exemptions       4           0.072727                0.000000              0.000000
# 36            NaN       NaN                          personal exemptions       1           0.018182                0.000000              0.131965
# 37            NaN       NaN                                   protection       2           0.036364                0.000000              0.041558
# 38            NaN       NaN                                public health       2           0.036364                0.000337              0.018182
# 39            NaN       NaN                          religious exemption       1           0.018182                0.000000              0.000000
# 40            NaN       NaN                         religious exemptions       1           0.018182                0.000000              0.131965
# 41            NaN       NaN                                  republicans       2           0.036364                0.000000              0.145455
# 42            NaN       NaN                            required vaccines       1           0.018182                0.000000              0.000000
# 43            NaN       NaN                               responsibility       1           0.018182                0.000000              0.000000
# 44            NaN       NaN                                         safe       1           0.018182                0.000000              0.000000
# 45            NaN       NaN                                      schools       1           0.018182                0.000000              0.000000
# 46            NaN       NaN                                      science       1           0.018182                0.000000              0.050505
# 47            NaN       NaN                                     senators       1           0.018182                0.000000              0.000000
# 48            NaN       NaN                                        shots       1           0.018182                0.000000              0.000000
# 49            NaN       NaN                                   supporters       1           0.018182                0.000000              0.000000
# 50            NaN       NaN                                   uninformed       2           0.036364                0.000000              0.000000
# 51            NaN       NaN                                 unvaccinated       1           0.018182                0.000000              0.018182
# 52            NaN       NaN                                   vaccinated       1           0.018182                0.000000              0.000000
# 53            NaN       NaN                            vaccine opponents       1           0.018182                0.000000              0.107236
# 54            NaN       NaN                         vaccine side effects       1           0.018182                0.000000              0.000000
# 55            NaN       NaN                                     vaccines       6           0.109091                0.002357              0.072727
#
# [3351 rows x 7 columns]

# %%
# save dataframe to csv
combined_df.to_csv('combined_df', encoding = 'utf-8')

# %% [markdown]
# - - -

# %% [raw]
# #### fix the thing ####

# %%
combined_df = pd.read_csv('combined_df')
combined_df
