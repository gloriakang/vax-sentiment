# %% [markdown]
# ## multi-graph
# 0. Network-wide statistics

# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from glob import glob

gml_files = glob('../output/network/*/*.gml')

# %%
def calculate_graph_inf(graph):
    graph.name = filename
    info = nx.info(graph)
    print info
    ## plot spring layout
    # plt.figure(figsize=(10,10))
    # nx.draw_spring(graph, arrows=True, with_labels=True)

    
def highest_centrality(cent_dict):
    """Returns a tuple (node,value) with the node
    with largest value from centrality dictionary."""
    # create ordered tuple of centrality data
    cent_items = [(b,a) for (a,b) in cent_dict.iteritems()]
    # sort in descending order
    cent_items.sort()
    cent_items.reverse()
    return tuple(reversed(cent_items[0]))

# %%
for graph_num, gml_graph in enumerate(gml_files):
    graph = nx.read_gml(gml_graph)
    ugraph = graph.to_undirected() ## to undirected graph
    (filepath, filename) = os.path.split(gml_graph)
    print('-' * 40)
    print(gml_graph)
    #calculate_graph_inf(graph)
    #calculate_graph_inf(ugraph)
    if graph_num == 4:
        break
# Out:
# ----------------------------------------
# ../output/network/positive/article2.gml
# ----------------------------------------
# ../output/network/positive/article1804.gml
# ----------------------------------------
# ../output/network/positive/article6247.gml
# ----------------------------------------
# ../output/network/positive/article4150.gml
# ----------------------------------------
# ../output/network/positive/article1105.gml

# %%
# create empty dataframe with columns

network_data_columns = ['name',
                    'sentiment',
                    '# nodes',
                    '# edges',
                    'avg degree',
                    'density',
                    'avg deg cent',
                    'avg bet cent',
                    'avg clo cent',
                    'highest degc',
                    'highest betc',
                    'highest cloc',
                    'avg in-deg',
                    'avg out-deg',
                    '# strong comp',
                    '# weak comp',
                    '# conn comp',
                    'avg node connect',
                    'deg assort coeff',
                    ]

network_data = pd.DataFrame(columns = network_data_columns)

# %%
# calculate variables for the first time

#(filepath, filename) = os.path.split(gml_graph)
sent = filepath.split('/')[-1]
nodes = nx.number_of_nodes(graph)
edges = nx.number_of_edges(graph)
density = nx.density(graph)
avg_deg_cen = np.array(nx.degree_centrality(graph).values()).mean()
avg_bet_cen = np.array(nx.betweenness_centrality(graph).values()).mean()
avg_clo_cen = np.array(nx.closeness_centrality(graph).values()).mean()
in_deg = sum(graph.in_degree().values())/float(nx.number_of_nodes(graph))
out_deg = sum(graph.out_degree().values())/float(nx.number_of_nodes(graph))
avg_deg = in_deg + out_deg
strong_comp = nx.number_strongly_connected_components(graph)
weak_comp =  nx.number_weakly_connected_components(graph)
avg_node_con = nx.average_node_connectivity(graph)
deg_assort_coeff = nx.degree_assortativity_coefficient(graph)
conn_comp = nx.number_connected_components(ugraph)
deg_cen = nx.degree_centrality(graph)
bet_cen = nx.betweenness_centrality(graph)
clo_cen = nx.closeness_centrality(graph)
highest_deg_cen = highest_centrality(deg_cen)
highest_bet_cen = highest_centrality(bet_cen)
highest_clo_cen = highest_centrality(clo_cen)

# save variables into list -- name:variable
# append dataframe for network-wide statistics

graph_values = {'name':filename,
                'sentiment':sent,
                '# nodes':nodes,
                '# edges':edges,
                'avg degree':avg_deg,
                'density':density,
                'avg deg cent':avg_deg_cen,
                'avg bet cent':avg_bet_cen,
                'avg clo cent':avg_clo_cen,
                'highest degc':highest_deg_cen,
                'highest betc':highest_bet_cen,
                'highest cloc':highest_clo_cen,
                'avg in-deg':in_deg,
                'avg out-deg':out_deg,
                '# strong comp':strong_comp,
                '# weak comp':weak_comp,
                '# conn comp':conn_comp,
                'avg node connect':avg_node_con,
                'deg assort coeff':deg_assort_coeff,
                }

# %%
def run_stats(graph, ugraph):
    graph = nx.read_gml(gml_graph)
    ugraph = graph.to_undirected()
    return network_data

def append_stats(network_data):
    run_stats(graph, ugraph)
    network_data = network_data.append(graph_values, ignore_index=True)
    return network_data

# %%
append_stats(network_data)
# Out:
#               name sentiment  # nodes  # edges  avg degree   density  \
# 0  article1105.gml  positive       38       31    1.631579  0.022048
#
#    avg deg cent  avg bet cent  avg clo cent  \
# 0      0.044097      0.000356      0.025693
#
#                                         highest degc  \
# 0  (parents who refuse to vaccinate their childre...
#
#                                         highest betc  \
# 0  (parents who refuse to vaccinate their childre...
#
#                 highest cloc  avg in-deg  avg out-deg  # strong comp  \
# 0  (parents, 0.172119487909)    0.815789     0.815789             37
#
#    # weak comp  # conn comp  avg node connect  deg assort coeff
# 0           10           10          0.035562          0.088923

# %%
network_data
# Out:
# Empty DataFrame
# Columns: [name, sentiment, # nodes, # edges, avg degree, density, avg deg cent, avg bet cent, avg clo cent, highest degc, highest betc, highest cloc, avg in-deg, avg out-deg, # strong comp, # weak comp, # conn comp, avg node connect, deg assort coeff]
# Index: []

# %%
#graph = directed, ugraph = undirected

for i, gml_graph in enumerate(gml_files):
    graph = nx.read_gml(gml_graph)
    ugraph = graph.to_undirected() ## to undirected graph
    print('-' * 40)
    print(gml_graph)
    #calculate_graph_inf(graph)
    #calculate_graph_inf(ugraph)
    if i==4:
        break
        
    for i in gml_files:
        run_stats(graph, ugraph)
        network_data = append_stats(network_data)
        #network_data = network_data.append(graph_values, ignore_index=True)
        if i==4:
            break
# Out:
# ----------------------------------------
# ../output/network/positive/article2.gml
# ----------------------------------------
# ../output/network/positive/article1804.gml
# ----------------------------------------
# ../output/network/positive/article6247.gml
# ----------------------------------------
# ../output/network/positive/article4150.gml
# ----------------------------------------
# ../output/network/positive/article1105.gml

# %%
network_data
# Out:
#                 name sentiment  # nodes  # edges  avg degree   density  \
# 0    article1105.gml  positive       38       31    1.631579  0.022048
# 1    article1105.gml  positive       38       31    1.631579  0.022048
# 2    article1105.gml  positive       38       31    1.631579  0.022048
# 3    article1105.gml  positive       38       31    1.631579  0.022048
# 4    article1105.gml  positive       38       31    1.631579  0.022048
# 5    article1105.gml  positive       38       31    1.631579  0.022048
# 6    article1105.gml  positive       38       31    1.631579  0.022048
# 7    article1105.gml  positive       38       31    1.631579  0.022048
# 8    article1105.gml  positive       38       31    1.631579  0.022048
# 9    article1105.gml  positive       38       31    1.631579  0.022048
# 10   article1105.gml  positive       38       31    1.631579  0.022048
# 11   article1105.gml  positive       38       31    1.631579  0.022048
# 7        0.044097      0.000356      0.025693
# 8        0.044097      0.000356      0.025693
# 9        0.044097      0.000356      0.025693
# 10       0.044097      0.000356      0.025693
# 11       0.044097      0.000356      0.025693
# 12       0.044097      0.000356      0.025693
# 13       0.044097      0.000356      0.025693
# 14       0.044097      0.000356      0.025693
# 15       0.044097      0.000356      0.025693
# 16       0.044097      0.000356      0.025693
# 17       0.044097      0.000356      0.025693
# 18       0.044097      0.000356      0.025693
# 19       0.044097      0.000356      0.025693
# 20       0.044097      0.000356      0.025693
# 21       0.044097      0.000356      0.025693
# 22       0.044097      0.000356      0.025693
# 23       0.044097      0.000356      0.025693
# 24       0.044097      0.000356      0.025693
# 25       0.044097      0.000356      0.025693
# 26       0.044097      0.000356      0.025693
# 27       0.044097      0.000356      0.025693
# 28       0.044097      0.000356      0.025693
# 29       0.044097      0.000356      0.025693
# ..            ...           ...           ...
# 170      0.044097      0.000356      0.025693
# 171      0.044097      0.000356      0.025693
# 172      0.044097      0.000356      0.025693
# 173      0.044097      0.000356      0.025693
# 174      0.044097      0.000356      0.025693
# 175      0.044097      0.000356      0.025693
# 176      0.044097      0.000356      0.025693
# 177      0.044097      0.000356      0.025693
# 178      0.044097      0.000356      0.025693
# 179      0.044097      0.000356      0.025693
# 180      0.044097      0.000356      0.025693
# 181      0.044097      0.000356      0.025693
# 182      0.044097      0.000356      0.025693
# 183      0.044097      0.000356      0.025693
# 184      0.044097      0.000356      0.025693
# 185      0.044097      0.000356      0.025693
# 186      0.044097      0.000356      0.025693
# 187      0.044097      0.000356      0.025693
# 188      0.044097      0.000356      0.025693
# 189      0.044097      0.000356      0.025693
# 190      0.044097      0.000356      0.025693
# 191      0.044097      0.000356      0.025693
# 192      0.044097      0.000356      0.025693
# 193      0.044097      0.000356      0.025693
# 194      0.044097      0.000356      0.025693
# 195      0.044097      0.000356      0.025693
# 196      0.044097      0.000356      0.025693
# 197      0.044097      0.000356      0.025693
# 198      0.044097      0.000356      0.025693
# 199      0.044097      0.000356      0.025693
#
#                                           highest degc  \
# 0    (parents who refuse to vaccinate their childre...
# 1    (parents who refuse to vaccinate their childre...
# 2    (parents who refuse to vaccinate their childre...
# 3    (parents who refuse to vaccinate their childre...
# 4    (parents who refuse to vaccinate their childre...
# 5    (parents who refuse to vaccinate their childre...
# 6    (parents who refuse to vaccinate their childre...
# 7    (parents who refuse to vaccinate their childre...
# 8    (parents who refuse to vaccinate their childre...
# 9    (parents who refuse to vaccinate their childre...
# 10   (parents who refuse to vaccinate their childre...
# 11   (parents who refuse to vaccinate their childre...
# 12   (parents who refuse to vaccinate their childre...
# 13   (parents who refuse to vaccinate their childre...
# 14   (parents who refuse to vaccinate their childre...
# 15   (parents who refuse to vaccinate their childre...
# 16   (parents who refuse to vaccinate their childre...
# 17   (parents who refuse to vaccinate their childre...
# 18   (parents who refuse to vaccinate their childre...
# 19   (parents who refuse to vaccinate their childre...
# 20   (parents who refuse to vaccinate their childre...
# 21   (parents who refuse to vaccinate their childre...
# ..                                                 ...
# 170  (parents who refuse to vaccinate their childre...
# 171  (parents who refuse to vaccinate their childre...
# 172  (parents who refuse to vaccinate their childre...
# 173  (parents who refuse to vaccinate their childre...
# 174  (parents who refuse to vaccinate their childre...
# 175  (parents who refuse to vaccinate their childre...
# 176  (parents who refuse to vaccinate their childre...
# 177  (parents who refuse to vaccinate their childre...
# 178  (parents who refuse to vaccinate their childre...
# 179  (parents who refuse to vaccinate their childre...
# 180  (parents who refuse to vaccinate their childre...
# 181  (parents who refuse to vaccinate their childre...
# 182  (parents who refuse to vaccinate their childre...
# 183  (parents who refuse to vaccinate their childre...
# 184  (parents who refuse to vaccinate their childre...
# 185  (parents who refuse to vaccinate their childre...
# 186  (parents who refuse to vaccinate their childre...
# 187  (parents who refuse to vaccinate their childre...
# 188  (parents who refuse to vaccinate their childre...
# 189  (parents who refuse to vaccinate their childre...
# 190  (parents who refuse to vaccinate their childre...
# 191  (parents who refuse to vaccinate their childre...
# 192  (parents who refuse to vaccinate their childre...
# 193  (parents who refuse to vaccinate their childre...
# 194  (parents who refuse to vaccinate their childre...
# 195  (parents who refuse to vaccinate their childre...
# 196  (parents who refuse to vaccinate their childre...
# 197  (parents who refuse to vaccinate their childre...
# 198  (parents who refuse to vaccinate their childre...
# 199  (parents who refuse to vaccinate their childre...
#
#                   highest cloc  avg in-deg  avg out-deg  # strong comp  \
# 0    (parents, 0.172119487909)    0.815789     0.815789             37
# 1    (parents, 0.172119487909)    0.815789     0.815789             37
# 2    (parents, 0.172119487909)    0.815789     0.815789             37
# 3    (parents, 0.172119487909)    0.815789     0.815789             37
# 4    (parents, 0.172119487909)    0.815789     0.815789             37
# 5    (parents, 0.172119487909)    0.815789     0.815789             37
# 6    (parents, 0.172119487909)    0.815789     0.815789             37
# 7    (parents, 0.172119487909)    0.815789     0.815789             37
# 8    (parents, 0.172119487909)    0.815789     0.815789             37
# 9    (parents, 0.172119487909)    0.815789     0.815789             37
# 10   (parents, 0.172119487909)    0.815789     0.815789             37
# 11   (parents, 0.172119487909)    0.815789     0.815789             37
# 12   (parents, 0.172119487909)    0.815789     0.815789             37
# 13   (parents, 0.172119487909)    0.815789     0.815789             37
# 14   (parents, 0.172119487909)    0.815789     0.815789             37
# 15   (parents, 0.172119487909)    0.815789     0.815789             37
# 16   (parents, 0.172119487909)    0.815789     0.815789             37
# 17   (parents, 0.172119487909)    0.815789     0.815789             37
# 18   (parents, 0.172119487909)    0.815789     0.815789             37
# 19   (parents, 0.172119487909)    0.815789     0.815789             37
# 20   (parents, 0.172119487909)    0.815789     0.815789             37
# 21   (parents, 0.172119487909)    0.815789     0.815789             37
# 22   (parents, 0.172119487909)    0.815789     0.815789             37
# 23   (parents, 0.172119487909)    0.815789     0.815789             37
# 24   (parents, 0.172119487909)    0.815789     0.815789             37
# 25   (parents, 0.172119487909)    0.815789     0.815789             37
# 26   (parents, 0.172119487909)    0.815789     0.815789             37
# 27   (parents, 0.172119487909)    0.815789     0.815789             37
# 28   (parents, 0.172119487909)    0.815789     0.815789             37
# 29   (parents, 0.172119487909)    0.815789     0.815789             37
# ..                         ...         ...          ...            ...
# 170  (parents, 0.172119487909)    0.815789     0.815789             37
# 171  (parents, 0.172119487909)    0.815789     0.815789             37
# 172  (parents, 0.172119487909)    0.815789     0.815789             37
# 173  (parents, 0.172119487909)    0.815789     0.815789             37
# 174  (parents, 0.172119487909)    0.815789     0.815789             37
# 175  (parents, 0.172119487909)    0.815789     0.815789             37
# 176  (parents, 0.172119487909)    0.815789     0.815789             37
# 177  (parents, 0.172119487909)    0.815789     0.815789             37
# 178  (parents, 0.172119487909)    0.815789     0.815789             37
# 179  (parents, 0.172119487909)    0.815789     0.815789             37
# 180  (parents, 0.172119487909)    0.815789     0.815789             37
# 181  (parents, 0.172119487909)    0.815789     0.815789             37
# 182  (parents, 0.172119487909)    0.815789     0.815789             37
# 183  (parents, 0.172119487909)    0.815789     0.815789             37
# 184  (parents, 0.172119487909)    0.815789     0.815789             37
# 185  (parents, 0.172119487909)    0.815789     0.815789             37
# 186  (parents, 0.172119487909)    0.815789     0.815789             37
# 187  (parents, 0.172119487909)    0.815789     0.815789             37
# 188  (parents, 0.172119487909)    0.815789     0.815789             37
# 189  (parents, 0.172119487909)    0.815789     0.815789             37
# 190  (parents, 0.172119487909)    0.815789     0.815789             37
# 191  (parents, 0.172119487909)    0.815789     0.815789             37
# 192  (parents, 0.172119487909)    0.815789     0.815789             37
# 193  (parents, 0.172119487909)    0.815789     0.815789             37
# 194  (parents, 0.172119487909)    0.815789     0.815789             37
# 195  (parents, 0.172119487909)    0.815789     0.815789             37
# 196  (parents, 0.172119487909)    0.815789     0.815789             37
# 197  (parents, 0.172119487909)    0.815789     0.815789             37
# 198  (parents, 0.172119487909)    0.815789     0.815789             37
# 199  (parents, 0.172119487909)    0.815789     0.815789             37
#
#      # weak comp  # conn comp  avg node connect  deg assort coeff
# 0             10           10          0.035562          0.088923
# 1             10           10          0.035562          0.088923
# 2             10           10          0.035562          0.088923
# 3             10           10          0.035562          0.088923
# 4             10           10          0.035562          0.088923
# 5             10           10          0.035562          0.088923
# 6             10           10          0.035562          0.088923
# 7             10           10          0.035562          0.088923
# 8             10           10          0.035562          0.088923
# 9             10           10          0.035562          0.088923
# 10            10           10          0.035562          0.088923
# 11            10           10          0.035562          0.088923
# 12            10           10          0.035562          0.088923
# 13            10           10          0.035562          0.088923
# 14            10           10          0.035562          0.088923
# 15            10           10          0.035562          0.088923
# 16            10           10          0.035562          0.088923
# 17            10           10          0.035562          0.088923
# 18            10           10          0.035562          0.088923
# 19            10           10          0.035562          0.088923
# 20            10           10          0.035562          0.088923
# 21            10           10          0.035562          0.088923
# 22            10           10          0.035562          0.088923
# 23            10           10          0.035562          0.088923
# 24            10           10          0.035562          0.088923
# 25            10           10          0.035562          0.088923
# 26            10           10          0.035562          0.088923
# 27            10           10          0.035562          0.088923
# 28            10           10          0.035562          0.088923
# 29            10           10          0.035562          0.088923
# ..           ...          ...               ...               ...
# 170           10           10          0.035562          0.088923
# 171           10           10          0.035562          0.088923
# 172           10           10          0.035562          0.088923
# 173           10           10          0.035562          0.088923
# 174           10           10          0.035562          0.088923
# 175           10           10          0.035562          0.088923
# 176           10           10          0.035562          0.088923
# 177           10           10          0.035562          0.088923
# 178           10           10          0.035562          0.088923
# 179           10           10          0.035562          0.088923
# 180           10           10          0.035562          0.088923
# 181           10           10          0.035562          0.088923
# 182           10           10          0.035562          0.088923
# 183           10           10          0.035562          0.088923
# 184           10           10          0.035562          0.088923
# 185           10           10          0.035562          0.088923
# 186           10           10          0.035562          0.088923
# 187           10           10          0.035562          0.088923
# 188           10           10          0.035562          0.088923
# 189           10           10          0.035562          0.088923
# 190           10           10          0.035562          0.088923
# 191           10           10          0.035562          0.088923
# 192           10           10          0.035562          0.088923
# 193           10           10          0.035562          0.088923
# 194           10           10          0.035562          0.088923
# 195           10           10          0.035562          0.088923
# 196           10           10          0.035562          0.088923
# 197           10           10          0.035562          0.088923
# 198           10           10          0.035562          0.088923
# 199           10           10          0.035562          0.088923
#
# [200 rows x 19 columns]

# %% [markdown]
# - - -

# %% [markdown]
# ## Network-wide variable calculations

# %%
# degree histogram: returns a list of frequencies of degrees
nx.degree_histogram(graph)

# %%
# degree centrality
#nx.degree_centrality(graph)
a = nx.degree_centrality(graph)
dfIn=pd.DataFrame.from_dict(a,orient='index')
dfIn.columns = ['degree centrality']
dfIn = dfIn.sort_values(by=['degree centrality'])
dfIn

# %%
# betweenness centrality
#nx.betweenness_centrality(graph)
a = nx.betweenness_centrality(graph)
dfIn=pd.DataFrame.from_dict(a,orient='index')
dfIn.columns = ['betweenness centrality']
dfIn = dfIn.sort_values(by=['betweenness centrality'])
dfIn

# %%
# closeness centrality
#nx.closeness_centrality(graph).values()
a = nx.closeness_centrality(graph)
dfIn=pd.DataFrame.from_dict(a,orient='index')
dfIn.columns = ['closeness centrality']
dfIn = dfIn.sort_values(by=['closeness centrality'])
dfIn

# %%
# in degree centrality
a = nx.in_degree_centrality(graph)
dfIn=pd.DataFrame.from_dict(a,orient='index')
dfIn.columns = ['in deg centrality']
dfIn = dfIn.sort_values(by=['in deg centrality'])
dfIn

# %%
# out degree centrality
b = nx.out_degree_centrality(graph)
dfIn=pd.DataFrame.from_dict(b,orient='index')
dfIn.columns = ['out deg centrality']
dfIn = dfIn.sort_values(by=['out deg centrality'])
dfIn

# %% [markdown]
# - - -

# %%
# current-flow betweenness centrality (graph must be connected; run for largest component)
#nx.current_flow_betweenness_centrality(graph)

# eigenvector centrality

# degree assortativity coefficient
# average neighbor degree; average degree connectivity (k nearest neighbors)

#nx.edge_connectivity(graph)
#nx.node_connectivity(graph)

# clustering coefficient (cannot be multigraph)
# nx.average_clustering(graph)

# %% [raw]
# print "Density ="
# print "Degree centrality ="
# print "Closeness centrality ="
# print "Betweenness centrality ="
# print "Degree assortativity coefficient ="
# print "Degree pearson correlation coefficient ="
# print "Average node connectivity ="
