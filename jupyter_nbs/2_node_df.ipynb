# %% [markdown]
# # node_df
# 0. node-level data (all articles)
# 1. network data + centrality data = combined_df
# 2. remove NaN values
# 3. out = node_df.csv

# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from glob import glob
pd.set_option('display.mpl_style', 'default') 
# display all the columns
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)


gml_files = glob('../output/network/*/*.gml')


def calculate_graph_inf(graph):
    graph.name = filename
    info = nx.info(graph)
    print info
    ## plot spring layout
    #plt.figure(figsize=(10,10))
    #nx.draw_spring(graph, arrows=True, with_labels=True)

def highest_centrality(cent_dict):
    """Returns a tuple (node,value) with the node
    with largest value from centrality dictionary."""
    # create ordered tuple of centrality data
    cent_items = [(b,a) for (a,b) in cent_dict.iteritems()]
    # sort in descending order
    cent_items.sort()
    cent_items.reverse()
    return tuple(reversed(cent_items[0]))

# %%
# create empty dataframe with columns

data_columns = ['name',
                'sentiment'
                ]
data = pd.DataFrame(columns = data_columns)
combined_df = pd.DataFrame()

# %%
# graph = directed, ugraph = undirected

for graph_num, gml_graph in enumerate(gml_files):
    graph = nx.read_gml(gml_graph)
    ugraph = graph.to_undirected()
    # adding missing edges back
    U = graph.to_undirected(reciprocal=True)
    e = U.edges()
    ugraph.add_edges_from(e)
    (filepath, filename) = os.path.split(gml_graph)
    print('-' * 40)
    print(gml_graph)
    #calculate_graph_inf(graph)
    #calculate_graph_inf(ugraph)

    # calculate variables and save into list
    sent = filepath.split('/')[-1]
    deg_cent = nx.degree_centrality(graph)
    bet_cent = nx.betweenness_centrality(graph)
    clo_cent = nx.closeness_centrality(graph)
    
    graph_values = {'name':filename,
                    'sentiment':sent,
                    }

    data = data.append(graph_values, ignore_index=True)
    
    #
    degree = nx.degree(graph)
    deg_df = pd.DataFrame.from_dict(degree, orient = 'index')
    deg_df.columns = ['degree']
    # degree centrality
    deg_cent = nx.degree_centrality(graph)
    dc_df = pd.DataFrame.from_dict(deg_cent, orient = 'index')
    dc_df.columns = ['degree centrality']
    # betweenness centrality
    bet_cent = nx.betweenness_centrality(graph)
    bc_df = pd.DataFrame.from_dict(bet_cent, orient = 'index')
    bc_df.columns = ['betweenness centrality']
    # closeness centrality
    clo_cent = nx.closeness_centrality(graph)
    cc_df = pd.DataFrame.from_dict(clo_cent, orient = 'index')
    cc_df.columns = ['closeness centrality']
    
    # concat node frames into node_df
    frames = [deg_df, dc_df, bc_df, cc_df]
    node_df = pd.concat(frames, axis = 1)
    node_df.index.name = 'node'
    node_df = node_df.reset_index()
    
    values = pd.DataFrame(graph_values, columns = ('name', 'sentiment'), index = [0])
    
    # df = merges graph_values with node_df for single graph and fill NaNs
    df = pd.concat([values, node_df], axis = 1)
    df = df.fillna(method='ffill')
    
    # append to combined_df
    combined_df = combined_df.append(df)
    
#    if graph_num == 2:
#        break
# Out:
# ----------------------------------------
# ../output/network/negative/article03.gml
# ----------------------------------------
# ../output/network/negative/article05.gml
# ----------------------------------------
# ../output/network/negative/article06.gml
# ----------------------------------------
# ../output/network/negative/article07.gml
# ----------------------------------------
# ../output/network/negative/article1.gml
# ----------------------------------------
# ../output/network/negative/article1001.gml
# ----------------------------------------
# ../output/network/negative/article1021.gml
# ----------------------------------------
# ../output/network/negative/article152.gml
# ----------------------------------------
# ../output/network/negative/article2308.gml
# ----------------------------------------
# ../output/network/negative/article3335.gml
# ----------------------------------------
# ../output/network/negative/article4106.gml
# ----------------------------------------
# ../output/network/negative/article432.gml
# ----------------------------------------
# ../output/network/negative/article5164.gml
# ----------------------------------------
# ../output/network/negative/article5717.gml
# ----------------------------------------
# ../output/network/negative/article5813.gml
# ----------------------------------------
# ../output/network/negative/article621.gml
# ----------------------------------------
# ../output/network/negative/article683.gml
# ----------------------------------------
# ../output/network/negative/article703.gml
# ----------------------------------------
# ../output/network/negative/article774.gml
# ----------------------------------------
# ../output/network/negative/article782.gml
# ----------------------------------------
# ../output/network/negative/article99.gml
# ----------------------------------------
# ../output/network/neutral/article2047.gml
# ----------------------------------------
# ../output/network/neutral/article532.gml
# ----------------------------------------
# ../output/network/neutral/article54.gml
# ----------------------------------------
# ../output/network/neutral/article63.gml
# ----------------------------------------
# ../output/network/neutral/article647.gml
# ----------------------------------------
# ../output/network/neutral/article756.gml
# ----------------------------------------
# ../output/network/positive/article02.gml
# ----------------------------------------
# ../output/network/positive/article1105.gml
# ----------------------------------------
# ../output/network/positive/article111.gml
# ----------------------------------------
# ../output/network/positive/article1542.gml
# ----------------------------------------
# ../output/network/positive/article1804.gml
# ----------------------------------------
# ../output/network/positive/article2.gml
# ----------------------------------------
# ../output/network/positive/article29.gml
# ----------------------------------------
# ../output/network/positive/article30.gml
# ----------------------------------------
# ../output/network/positive/article31.gml
# ----------------------------------------
# ../output/network/positive/article36.gml
# ----------------------------------------
# ../output/network/positive/article37.gml
# ----------------------------------------
# ../output/network/positive/article4150.gml
# ----------------------------------------
# ../output/network/positive/article4210.gml
# ----------------------------------------
# ../output/network/positive/article4303.gml
# ----------------------------------------
# ../output/network/positive/article46.gml
# ----------------------------------------
# ../output/network/positive/article5.gml
# ----------------------------------------
# ../output/network/positive/article5077.gml
# ----------------------------------------
# ../output/network/positive/article609.gml
# ----------------------------------------
# ../output/network/positive/article620.gml
# ----------------------------------------
# ../output/network/positive/article6247.gml
# ----------------------------------------
# ../output/network/positive/article664.gml
# ----------------------------------------
# ../output/network/positive/article665.gml
# ----------------------------------------
# ../output/network/positive/article828.gml

# %%
combined_df
# Out:
#               name sentiment                                         node  degree  degree centrality  betweenness centrality  closeness centrality
# 0    article03.gml  negative                                       parent       1           0.058824                0.000000              0.058824
# 1    article03.gml  negative                              vaccine dangers       2           0.117647                0.003676              0.058824
# 2    article03.gml  negative                        unvaccinated children       2           0.117647                0.011029              0.088235
# 3    article03.gml  negative                        vaccines are not safe       1           0.058824                0.000000              0.000000
# 4    article03.gml  negative                                         safe       1           0.058824                0.000000              0.000000
# 5    article03.gml  negative  parents who know that vaccines are not safe       1           0.058824                0.000000              0.058824
# 6    article03.gml  negative                     vaccine-injured children       1           0.058824                0.000000              0.000000
# 7    article03.gml  negative                          vaccinated children       2           0.117647                0.000000              0.133690
# 8    article03.gml  negative                                     vaccines       2           0.117647                0.011029              0.058824
# 9    article03.gml  negative                                      doctors       1           0.058824                0.000000              0.058824
# 10   article03.gml  negative                                      parents       3           0.176471                0.000000              0.210084
# 11   article03.gml  negative                         consent for vaccines       2           0.117647                0.003676              0.058824
# 12   article03.gml  negative                                immune system       2           0.117647                0.014706              0.078431
# 13   article03.gml  negative                          preventable disease       1           0.058824                0.000000              0.000000
# 14   article03.gml  negative                                     truthful       1           0.058824                0.000000              0.000000
# 15   article03.gml  negative                                     children       1           0.058824                0.000000              0.000000
# 16   article03.gml  negative                         get child vaccinated       1           0.058824                0.000000              0.000000
# 17   article03.gml  negative                        vaccine consent forms       1           0.058824                0.000000              0.000000
# 0    article05.gml  negative                                   Jim Carrey       7           0.333333                0.000000              0.321429
# 1    article05.gml  negative                      neurotoxins in vaccines       3           0.142857                0.004762              0.047619
# 2    article05.gml  negative                           mandatory vaccines       5           0.238095                0.009524              0.142857
# 3    article05.gml  negative                                controversial       1           0.047619                0.000000              0.000000
# 4    article05.gml  negative                       governor of California       1           0.047619                0.000000              0.047619
# 5    article05.gml  negative                                     children       1           0.047619                0.000000              0.000000
# 6    article05.gml  negative                                      mercury       2           0.095238                0.000000              0.000000
# 7    article05.gml  negative                              vaccine dangers       1           0.047619                0.000000              0.000000
# 8    article05.gml  negative                                       SB 277       5           0.238095                0.004762              0.047619
# 9    article05.gml  negative                                     vaccines       2           0.095238                0.000000              0.000000
# 10   article05.gml  negative                           poisoning children       2           0.095238                0.000000              0.108844
# 11   article05.gml  negative                                   thimerosal       2           0.095238                0.002381              0.047619
# ..             ...       ...                                          ...     ...                ...                     ...                   ...
# 26  article828.gml  positive                                        myths       2           0.036364                0.000337              0.018182
# 27  article828.gml  positive                                    officials       1           0.018182                0.000000              0.032727
# 28  article828.gml  positive                                     opt-outs       1           0.018182                0.000000              0.000000
# 29  article828.gml  positive                        overwhelming approval       1           0.018182                0.000000              0.000000
# 30  article828.gml  positive                              parental rights       2           0.036364                0.000000              0.000000
# 31  article828.gml  positive                                      parents       4           0.072727                0.000000              0.054545
# 32  article828.gml  positive                                  party lines       1           0.018182                0.000000              0.000000
# 33  article828.gml  positive                                       people       1           0.018182                0.000000              0.000000
# 34  article828.gml  positive                    personal belief exemption       3           0.054545                0.000673              0.036364
# 35  article828.gml  positive                   personal belief exemptions       4           0.072727                0.000000              0.000000
# 36  article828.gml  positive                          personal exemptions       1           0.018182                0.000000              0.131965
# 37  article828.gml  positive                                   protection       2           0.036364                0.000000              0.041558
# 38  article828.gml  positive                                public health       2           0.036364                0.000337              0.018182
# 39  article828.gml  positive                          religious exemption       1           0.018182                0.000000              0.000000
# 40  article828.gml  positive                         religious exemptions       1           0.018182                0.000000              0.131965
# 41  article828.gml  positive                                  republicans       2           0.036364                0.000000              0.145455
# 42  article828.gml  positive                            required vaccines       1           0.018182                0.000000              0.000000
# 43  article828.gml  positive                               responsibility       1           0.018182                0.000000              0.000000
# 44  article828.gml  positive                                         safe       1           0.018182                0.000000              0.000000
# 45  article828.gml  positive                                      schools       1           0.018182                0.000000              0.000000
# 46  article828.gml  positive                                      science       1           0.018182                0.000000              0.050505
# 47  article828.gml  positive                                     senators       1           0.018182                0.000000              0.000000
# 48  article828.gml  positive                                        shots       1           0.018182                0.000000              0.000000
# 49  article828.gml  positive                                   supporters       1           0.018182                0.000000              0.000000
# 50  article828.gml  positive                                   uninformed       2           0.036364                0.000000              0.000000
# 51  article828.gml  positive                                 unvaccinated       1           0.018182                0.000000              0.018182
# 52  article828.gml  positive                                   vaccinated       1           0.018182                0.000000              0.000000
# 53  article828.gml  positive                            vaccine opponents       1           0.018182                0.000000              0.107236
# 54  article828.gml  positive                         vaccine side effects       1           0.018182                0.000000              0.000000
# 55  article828.gml  positive                                     vaccines       6           0.109091                0.002357              0.072727
#
# [3351 rows x 7 columns]

# %%
# save dataframe to csv
combined_df.to_csv('node_df', encoding = 'utf-8')

# %% [markdown]
# - - -

# %% [raw]
# #### read the thing ####

# %%
node_df = pd.read_csv('node_df')
node_df
# Out:
#       Unnamed: 0            name sentiment                                         node  degree  degree centrality  betweenness centrality  closeness centrality
# 0              0   article03.gml  negative                                       parent       1           0.058824                0.000000              0.058824
# 1              1   article03.gml  negative                              vaccine dangers       2           0.117647                0.003676              0.058824
# 2              2   article03.gml  negative                        unvaccinated children       2           0.117647                0.011029              0.088235
# 3              3   article03.gml  negative                        vaccines are not safe       1           0.058824                0.000000              0.000000
# 4              4   article03.gml  negative                                         safe       1           0.058824                0.000000              0.000000
# 5              5   article03.gml  negative  parents who know that vaccines are not safe       1           0.058824                0.000000              0.058824
# 6              6   article03.gml  negative                     vaccine-injured children       1           0.058824                0.000000              0.000000
# 7              7   article03.gml  negative                          vaccinated children       2           0.117647                0.000000              0.133690
# 8              8   article03.gml  negative                                     vaccines       2           0.117647                0.011029              0.058824
# 9              9   article03.gml  negative                                      doctors       1           0.058824                0.000000              0.058824
# 10            10   article03.gml  negative                                      parents       3           0.176471                0.000000              0.210084
# 11            11   article03.gml  negative                         consent for vaccines       2           0.117647                0.003676              0.058824
# 12            12   article03.gml  negative                                immune system       2           0.117647                0.014706              0.078431
# 13            13   article03.gml  negative                          preventable disease       1           0.058824                0.000000              0.000000
# 14            14   article03.gml  negative                                     truthful       1           0.058824                0.000000              0.000000
# 15            15   article03.gml  negative                                     children       1           0.058824                0.000000              0.000000
# 16            16   article03.gml  negative                         get child vaccinated       1           0.058824                0.000000              0.000000
# 17            17   article03.gml  negative                        vaccine consent forms       1           0.058824                0.000000              0.000000
# 18             0   article05.gml  negative                                   Jim Carrey       7           0.333333                0.000000              0.321429
# 19             1   article05.gml  negative                      neurotoxins in vaccines       3           0.142857                0.004762              0.047619
# 20             2   article05.gml  negative                           mandatory vaccines       5           0.238095                0.009524              0.142857
# 21             3   article05.gml  negative                                controversial       1           0.047619                0.000000              0.000000
# 22             4   article05.gml  negative                       governor of California       1           0.047619                0.000000              0.047619
# 23             5   article05.gml  negative                                     children       1           0.047619                0.000000              0.000000
# 24             6   article05.gml  negative                                      mercury       2           0.095238                0.000000              0.000000
# 25             7   article05.gml  negative                              vaccine dangers       1           0.047619                0.000000              0.000000
# 26             8   article05.gml  negative                                       SB 277       5           0.238095                0.004762              0.047619
# 27             9   article05.gml  negative                                     vaccines       2           0.095238                0.000000              0.000000
# 28            10   article05.gml  negative                           poisoning children       2           0.095238                0.000000              0.108844
# 29            11   article05.gml  negative                                   thimerosal       2           0.095238                0.002381              0.047619
# ...          ...             ...       ...                                          ...     ...                ...                     ...                   ...
# 3321          26  article828.gml  positive                                        myths       2           0.036364                0.000337              0.018182
# 3322          27  article828.gml  positive                                    officials       1           0.018182                0.000000              0.032727
# 3323          28  article828.gml  positive                                     opt-outs       1           0.018182                0.000000              0.000000
# 3324          29  article828.gml  positive                        overwhelming approval       1           0.018182                0.000000              0.000000
# 3325          30  article828.gml  positive                              parental rights       2           0.036364                0.000000              0.000000
# 3326          31  article828.gml  positive                                      parents       4           0.072727                0.000000              0.054545
# 3327          32  article828.gml  positive                                  party lines       1           0.018182                0.000000              0.000000
# 3328          33  article828.gml  positive                                       people       1           0.018182                0.000000              0.000000
# 3329          34  article828.gml  positive                    personal belief exemption       3           0.054545                0.000673              0.036364
# 3330          35  article828.gml  positive                   personal belief exemptions       4           0.072727                0.000000              0.000000
# 3331          36  article828.gml  positive                          personal exemptions       1           0.018182                0.000000              0.131965
# 3332          37  article828.gml  positive                                   protection       2           0.036364                0.000000              0.041558
# 3333          38  article828.gml  positive                                public health       2           0.036364                0.000337              0.018182
# 3334          39  article828.gml  positive                          religious exemption       1           0.018182                0.000000              0.000000
# 3335          40  article828.gml  positive                         religious exemptions       1           0.018182                0.000000              0.131965
# 3336          41  article828.gml  positive                                  republicans       2           0.036364                0.000000              0.145455
# 3337          42  article828.gml  positive                            required vaccines       1           0.018182                0.000000              0.000000
# 3338          43  article828.gml  positive                               responsibility       1           0.018182                0.000000              0.000000
# 3339          44  article828.gml  positive                                         safe       1           0.018182                0.000000              0.000000
# 3340          45  article828.gml  positive                                      schools       1           0.018182                0.000000              0.000000
# 3341          46  article828.gml  positive                                      science       1           0.018182                0.000000              0.050505
# 3342          47  article828.gml  positive                                     senators       1           0.018182                0.000000              0.000000
# 3343          48  article828.gml  positive                                        shots       1           0.018182                0.000000              0.000000
# 3344          49  article828.gml  positive                                   supporters       1           0.018182                0.000000              0.000000
# 3345          50  article828.gml  positive                                   uninformed       2           0.036364                0.000000              0.000000
# 3346          51  article828.gml  positive                                 unvaccinated       1           0.018182                0.000000              0.018182
# 3347          52  article828.gml  positive                                   vaccinated       1           0.018182                0.000000              0.000000
# 3348          53  article828.gml  positive                            vaccine opponents       1           0.018182                0.000000              0.107236
# 3349          54  article828.gml  positive                         vaccine side effects       1           0.018182                0.000000              0.000000
# 3350          55  article828.gml  positive                                     vaccines       6           0.109091                0.002357              0.072727
#
# [3351 rows x 8 columns]
