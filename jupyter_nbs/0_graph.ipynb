# %%
neutral sentiment graph

# %%
# 1_network_df

import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from glob import glob

pd.set_option('display.mpl_style', 'default') 
pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

gml_files = glob('../output/network/article_neu1.gml')

def calculate_graph_inf(graph):
    graph.name = filename
    info = nx.info(graph)
    print info
    #plt.figure(figsize=(10,10))
    #nx.draw_spring(graph, arrows=True, with_labels=True)

def highest_centrality(cent_dict):
    """Returns a tuple (node,value) with the node
    with largest value from centrality dictionary."""
    # create ordered tuple of centrality data
    cent_items = [(b,a) for (a,b) in cent_dict.iteritems()]
    # sort in descending order
    cent_items.sort()
    cent_items.reverse()
    return tuple(reversed(cent_items[0]))

# %%
# create empty dataframe with columns
network_data_columns = ['name',
                    'sentiment',
                    'n nodes',
                    'n edges',
                    'avg degree',
                    'density',
                    'avg deg cent',
                    'avg bet cent',
                    'avg clo cent',
                    'highest degc',
                    'highest betc',
                    'highest cloc',
                    'avg node connect',
                    'deg assort coeff',
                    'avg in-deg',
                    'avg out-deg',
                    'n strong comp',
                    'n weak comp',
                    'n conn comp',
                    'Gc size'
                    ]

network_data = pd.DataFrame(columns = network_data_columns)

# %%
# graph = directed, ugraph = undirected
for graph_num, gml_graph in enumerate(gml_files):
    graph = nx.read_gml(gml_graph)
    ugraph = graph.to_undirected() #to undirected graph
    U = graph.to_undirected(reciprocal=True)
    e = U.edges()
    ugraph.add_edges_from(e)
    (filepath, filename) = os.path.split(gml_graph)
    print('-' * 40)
    print(gml_graph)
    calculate_graph_inf(graph) #ugraph exists too
    
    # calculate variables
    sent = filepath.split('/')[-1]
    nodes = nx.number_of_nodes(graph)
    edges = nx.number_of_edges(graph)
    density = float("{0:.4f}".format(nx.density(graph)))
    avg_deg_cen = np.array(nx.degree_centrality(graph).values()).mean()
    avg_bet_cen = np.array(nx.betweenness_centrality(graph).values()).mean()
    avg_clo_cen = np.array(nx.closeness_centrality(graph).values()).mean()
    in_deg = sum(graph.in_degree().values())/float(nx.number_of_nodes(graph))
    out_deg = sum(graph.out_degree().values())/float(nx.number_of_nodes(graph))
    avg_deg = float("{0:.4f}".format(in_deg + out_deg))
    strong_comp = nx.number_strongly_connected_components(graph)
    weak_comp =  nx.number_weakly_connected_components(graph)
    avg_node_con = float("{0:.4f}".format((nx.average_node_connectivity(graph))))
    deg_assort_coeff = float("{0:.4f}".format((nx.degree_assortativity_coefficient(graph))))
    conn_comp = nx.number_connected_components(ugraph)
    deg_cen = nx.degree_centrality(graph)
    bet_cen = nx.betweenness_centrality(graph)
    clo_cen = nx.closeness_centrality(graph)
    highest_deg_cen = highest_centrality(deg_cen)
    highest_bet_cen = highest_centrality(bet_cen)
    highest_clo_cen = highest_centrality(clo_cen)
    Gc = len(max(nx.connected_component_subgraphs(ugraph), key=len))

    # save variables into list
    graph_values = {'name':filename,
                    'sentiment':sent,
                    'n nodes':nodes,
                    'n edges':edges,
                    'avg degree':avg_deg,
                    'density':density,
                    'avg deg cent':"%.4f" % avg_deg_cen,
                    'avg bet cent':"%.4f" % avg_bet_cen,
                    'avg clo cent':"%.4f" % avg_clo_cen,
                    'highest degc':highest_deg_cen,
                    'highest betc':highest_bet_cen,
                    'highest cloc':highest_clo_cen,
                    'avg node connect':avg_node_con,
                    'deg assort coeff':deg_assort_coeff,
                    'avg in-deg':"%.4f" % in_deg,
                    'avg out-deg':"%.4f" % out_deg,
                    'n strong comp':strong_comp,
                    'n weak comp':weak_comp,
                    'n conn comp':conn_comp,
                    'Gc size':Gc
                    }
    
    network_data = network_data.append(graph_values, ignore_index=True)
# Out:
# ----------------------------------------
# ../output/network/article_neu1.gml
# Name: article_neu1.gml
# Type: MultiDiGraph
# Number of nodes: 212
# Number of edges: 237
# Average in degree:   1.1179
# Average out degree:   1.1179

# %%
network_data

# save to csv
#network_data.to_csv('output/network_df_neg.csv', encoding = 'utf-8')
# Out:
#                name sentiment  n nodes  n edges  avg degree  density avg deg cent avg bet cent avg clo cent              highest degc                highest betc              highest cloc  avg node connect  deg assort coeff avg in-deg avg out-deg  n strong comp  n weak comp  n conn comp  Gc size
# 0  article_neu1.gml   network      212      237      2.2358   0.0053       0.0106       0.0003       0.0103  (SB 277, 0.156398104265)  (SB 277, 0.00895960279847)  (SB 277, 0.101616950098)            0.0257           -0.1193     1.1179      1.1179            209           17           17      152

# %% [markdown]
# - - -

# %%
# 2_node_df

# %%
# create empty dataframe with columns
data_columns = ['name',
                'sentiment'
                ]
data = pd.DataFrame(columns = data_columns)
combined_df = pd.DataFrame()

# %%
# graph = directed, ugraph = undirected
for graph_num, gml_graph in enumerate(gml_files):
    print('-' * 40)
    print(gml_graph)
    calculate_graph_inf(graph)
    calculate_graph_inf(ugraph)

    # calculate variables and save into list
    sent = filepath.split('/')[-1]
    deg_cent = nx.degree_centrality(graph)
    bet_cent = nx.betweenness_centrality(graph)
    clo_cent = nx.closeness_centrality(graph)
    graph_values = {'name':filename,
                    'sentiment':sent,
                    }
    data = data.append(graph_values, ignore_index=True)

    degree = nx.degree(graph)
    deg_df = pd.DataFrame.from_dict(degree, orient = 'index')
    deg_df.columns = ['degree']
    # degree centrality
    deg_cent = nx.degree_centrality(graph)
    dc_df = pd.DataFrame.from_dict(deg_cent, orient = 'index')
    dc_df.columns = ['degree centrality']
    # betweenness centrality
    bet_cent = nx.betweenness_centrality(graph)
    bc_df = pd.DataFrame.from_dict(bet_cent, orient = 'index')
    bc_df.columns = ['betweenness centrality']
    # closeness centrality
    clo_cent = nx.closeness_centrality(graph)
    cc_df = pd.DataFrame.from_dict(clo_cent, orient = 'index')
    cc_df.columns = ['closeness centrality']
    
    # concat node frames into node_df
    frames = [deg_df, dc_df, bc_df, cc_df]
    node_df = pd.concat(frames, axis = 1)
    node_df.index.name = 'node'
    node_df = node_df.reset_index()
    
    values = pd.DataFrame(graph_values, columns = ('name', 'sentiment'), index = [0])
    
    # df = merges graph_values with node_df for single graph and fill NaNs
    df = pd.concat([values, node_df], axis = 1)
    df = df.fillna(method='ffill')
    combined_df = combined_df.append(df)
# Out:
# ----------------------------------------
# ../output/network/article_neu1.gml
# Name: article_neu1.gml
# Type: MultiDiGraph
# Number of nodes: 212
# Number of edges: 237
# Average in degree:   1.1179
# Average out degree:   1.1179
# Name: article_neu1.gml
# Type: MultiGraph
# Number of nodes: 212
# Number of edges: 237
# Average degree:   2.2358

# %%
combined_df

# save dataframe to csv
#combined_df.to_csv('1_df.csv', encoding = 'utf-8')
# Out:
#                  name sentiment                                 node  degree  degree centrality  betweenness centrality  closeness centrality
# 0    article_neu1.gml   network                       7-11 year olds       2           0.009479                0.000000              0.021666
# 1    article_neu1.gml   network       Alfred and Lisa Claire Dwoskin       1           0.004739                0.000000              0.000000
# 2    article_neu1.gml   network                            Americans       1           0.004739                0.000000              0.000000
# 3    article_neu1.gml   network                     Andrew Wakefield       5           0.023697                0.000948              0.041013
# 4    article_neu1.gml   network                            Australia       1           0.004739                0.000000              0.000000
# 5    article_neu1.gml   network                          Barry Segal       1           0.004739                0.000000              0.029998
# 6    article_neu1.gml   network                            Ben Allen       4           0.018957                0.000000              0.062977
# 7    article_neu1.gml   network                                  CDC       4           0.018957                0.001083              0.008531
# 8    article_neu1.gml   network                           California       1           0.004739                0.000000              0.000000
# 9    article_neu1.gml   network                 Chairwoman Carol Liu       2           0.009479                0.000000              0.063266
# 10   article_neu1.gml   network  Children's Hospital of Philadelphia       1           0.004739                0.000000              0.000000
# 11   article_neu1.gml   network                       Chris Christie       3           0.014218                0.000000              0.014218
# 12   article_neu1.gml   network                         Connie Leyva       3           0.014218                0.000000              0.061927
# 13   article_neu1.gml   network          Disneyland measles outbreak       1           0.004739                0.000000              0.000000
# 14   article_neu1.gml   network                      Dr. Anna Acosta       2           0.009479                0.000000              0.011848
# 15   article_neu1.gml   network                       Dr. Paul Offit       3           0.014218                0.000000              0.032314
# 16   article_neu1.gml   network                         Drew Downing       1           0.004739                0.000000              0.004739
# 17   article_neu1.gml   network            Dwoskin Family Foundation       8           0.037915                0.000000              0.038389
# 18   article_neu1.gml   network                     Focus for Health       4           0.018957                0.000519              0.037420
# 19   article_neu1.gml   network                        Gambhir study       3           0.014218                0.000000              0.014218
# 20   article_neu1.gml   network                    Generation Rescue       4           0.018957                0.000767              0.033407
# 21   article_neu1.gml   network        Immunization Action Coalition       1           0.004739                0.000000              0.008425
# 22   article_neu1.gml   network                       Jenny McCarthy       3           0.014218                0.000000              0.000000
# 23   article_neu1.gml   network                Lisa and J.B. Handley       1           0.004739                0.000000              0.000000
# 24   article_neu1.gml   network                          MMR vaccine       1           0.004739                0.000000              0.010833
# 25   article_neu1.gml   network  National Vaccine Information Center       2           0.009479                0.000023              0.004739
# 26   article_neu1.gml   network           PLOS Computational Biology       1           0.004739                0.000000              0.052737
# 27   article_neu1.gml   network                       Pez dispensers       1           0.004739                0.000000              0.000000
# 28   article_neu1.gml   network                            Rand Paul       3           0.014218                0.000000              0.014218
# 29   article_neu1.gml   network                         Renee Gentry       1           0.004739                0.000000              0.004739
# ..                ...       ...                                  ...     ...                ...                     ...                   ...
# 182  article_neu1.gml   network                         upward trend       2           0.009479                0.000000              0.012638
# 183  article_neu1.gml   network                  vaccinated children       2           0.009479                0.000384              0.004739
# 184  article_neu1.gml   network                          vaccination       4           0.018957                0.000812              0.009479
# 185  article_neu1.gml   network                vaccination exemption       3           0.014218                0.000384              0.004739
# 186  article_neu1.gml   network                 vaccination schedule       1           0.004739                0.000000              0.000000
# 187  article_neu1.gml   network                      vaccine allergy       1           0.004739                0.000000              0.000000
# 188  article_neu1.gml   network                       vaccine choice       1           0.004739                0.000000              0.000000
# 189  article_neu1.gml   network                     vaccine concerns       1           0.004739                0.000000              0.000000
# 190  article_neu1.gml   network                     vaccine coverage       1           0.004739                0.000000              0.000000
# 191  article_neu1.gml   network                       vaccine debate       4           0.018957                0.000000              0.021327
# 192  article_neu1.gml   network                     vaccine duration       2           0.009479                0.000000              0.000000
# 193  article_neu1.gml   network                     vaccine efficacy       3           0.014218                0.000158              0.056286
# 194  article_neu1.gml   network                     vaccine reaction       1           0.004739                0.000000              0.000000
# 195  article_neu1.gml   network                      vaccine refusal       2           0.009479                0.000000              0.004739
# 196  article_neu1.gml   network                         vaccine risk       1           0.004739                0.000000              0.004739
# 197  article_neu1.gml   network                        vaccine risks       2           0.009479                0.000000              0.000000
# 198  article_neu1.gml   network                       vaccine safety       2           0.009479                0.000000              0.000000
# 199  article_neu1.gml   network                  vaccine-autism link       4           0.018957                0.000000              0.000000
# 200  article_neu1.gml   network             vaccine-injured children       3           0.014218                0.000000              0.000000
# 201  article_neu1.gml   network         vaccine-preventable diseases       1           0.004739                0.000000              0.000000
# 202  article_neu1.gml   network                             vaccines      17           0.080569                0.004401              0.065651
# 203  article_neu1.gml   network   vaccines cause childhood illnesses       1           0.004739                0.000000              0.000000
# 204  article_neu1.gml   network         vaccines should be voluntary       1           0.004739                0.000000              0.000000
# 205  article_neu1.gml   network                             vomiting       1           0.004739                0.000000              0.000000
# 206  article_neu1.gml   network                 waning effectiveness       2           0.009479                0.000000              0.000000
# 207  article_neu1.gml   network                      waning immunity       1           0.004739                0.000000              0.027321
# 208  article_neu1.gml   network           wealthy family foundations       1           0.004739                0.000000              0.000000
# 209  article_neu1.gml   network                   whole-cell vaccine       5           0.023697                0.008034              0.069044
# 210  article_neu1.gml   network                       whooping cough       2           0.009479                0.000000              0.015511
# 211  article_neu1.gml   network                         young people       1           0.004739                0.000000              0.004739
#
# [212 rows x 7 columns]

# %% [markdown]
# - - -

# %%
# 7_negative_graph_calculation

# %%
def drawIt(graph, what = 'graph'):
    nsize = graph.number_of_nodes()
    print "Drawing %s of size %s:" % (what, nsize)
    
    if nsize > 20:
        plt.figure(figsize=(10, 10))
        if nsize > 40:
            nx.draw_spring(graph, with_labels = True, node_size = 70, font_size = 12)
        else:
            nx.draw_spring(graph, with_labels = True)
    else:
        nx.draw_spring(graph, with_labels = True)
    plt.show()

def describeGraph(graph):
    components = sorted(nx.connected_components(graph), key = len, reverse = True)
    cc = [len(c) for c in components]
    subgraphs = list(nx.connected_component_subgraphs(graph))
    params = (graph.number_of_edges(),graph.number_of_nodes(),len(cc))
    print "Graph has %s nodes, %s edges, %s connected components\n" % params
    drawIt(graph)
    for sub in components:
        drawIt(graph.subgraph(sub), what = 'component')

# %%
# components and connectivity

# list of connected components (sets of nodes), starting with largest
print "List of connected components =", [len(c) for c in sorted(nx.connected_components(ugraph), key=len, reverse=True)]

# generate connected components as subgraphs; Gc is largest component
subgraphs = list(nx.connected_component_subgraphs(ugraph))

# greatest component
Gc = max(nx.connected_component_subgraphs(ugraph), key=len)
print "Size of greatest component =", len(Gc)

# returns all minimum k cutsets of an undirected graph
# i.e., the set(s) of nodes of cardinality equal to the node connectivity of G
# thus if removed, would break G into two or more connected components
cutsets = list(nx.all_node_cuts(Gc))
print "# of cutsets =", len(cutsets)

# returns a set of nodes or edges of minimum cardinality that disconnects G
print "Min node cut =", nx.minimum_node_cut(Gc, s='vaccines', t='autism')
print "Min edge cut =", nx.minimum_edge_cut(Gc)
# Out:
# List of connected components = [152, 18, 6, 4, 4, 4, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2]
# Size of greatest component = 152
# # of cutsets = 35
# Min node cut = set([u'Focus for Health'])
# Min edge cut = set([(u'personal belief', u'kindergarteners')])

# %%
############ fix below

nx.minimum_node_cut(Gc, s='vaccines', t='autism')

# %%
##
a = nx.minimum_edge_cut(Gc, s='autism', t='vaccines')
a

##
labels = nx.get_edge_attributes(Gc,'edge')
edgelabels = {}
for e in labels.keys():
    e1 = e[0:2]
    edgelabels[e1]=labels[e]
edgelabels

##
for e in a:
    if edgelabels.has_key(e):
        print e,edgelabels[e]
    else:
        rev_e = e[::-1]
        print rev_e, edgelabels[rev_e]

# this takes forever
# average connectivity k of a graph G is the average of local node connectivity over all pairs of nodes of G
#nx.average_node_connectivity(Gc)

# NEW SUMMARY
print "List of connected components =", [len(c) for c in sorted(nx.connected_components(ugraph), key=len, reverse=True)]
print "Size of greatest component =", len(Gc)
print "# of cutsets =", len(cutsets)
print "Min node cut =", nx.minimum_node_cut(Gc)
print "Min edge cut =", nx.minimum_edge_cut(Gc)

# %% [markdown]
# - - -

# %%
# 8_single_calc_neg

# %%
#describeGraph(ugraph)

# %%
# degree histogram: returns a list of frequencies of degrees
print nx.degree_histogram(graph)

# %%
# degree rank plot (undirected)
degree_sequence=sorted(nx.degree(ugraph).values(),reverse=True) # degree sequence
#print "Degree sequence", degree_sequence
dmax=max(degree_sequence)

plt.loglog(degree_sequence,'b-',marker='o')
plt.title("Degree rank plot")
plt.ylabel("degree")
plt.xlabel("rank")

# draw graph in inset
plt.axes([0.45,0.45,0.45,0.45])
Gcc=sorted(nx.connected_component_subgraphs(ugraph), key = len, reverse=True)[0]
pos=nx.spring_layout(Gcc)
plt.axis('off')
nx.draw_networkx_nodes(Gcc,pos,node_size=20)
nx.draw_networkx_edges(Gcc,pos,alpha=0.4)

plt.show()

# %%
# degree centrality
a = nx.degree_centrality(graph)
dfIn=pd.DataFrame.from_dict(a,orient='index')
dfIn.columns = ['degree centrality']
dfIn = dfIn.sort_values(by=['degree centrality'])
dfIn

# betweenness centrality
a = nx.betweenness_centrality(graph)
dfIn=pd.DataFrame.from_dict(a,orient='index')
dfIn.columns = ['betweenness centrality']
dfIn = dfIn.sort_values(by=['betweenness centrality'])
dfIn

# closeness centrality
a = nx.closeness_centrality(graph)
dfIn=pd.DataFrame.from_dict(a,orient='index')
dfIn.columns = ['closeness centrality']
dfIn = dfIn.sort_values(by=['closeness centrality'])
dfIn
